# %%
import library as l

import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import datetime
import os

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

from scipy.stats import linregress

from collections import defaultdict
import json

# %%
def load_previous_data(indices, file='aggressive_dedup.json'):
    data = defaultdict(list)
    time = defaultdict(list)
    #ratings = defaultdict(list)
    
    idx = sorted([item for sublist in indices.values() for item in sublist])
    x = sorted(list(indices.keys()))
    for yr in x:
        data[yr] = list(np.zeros(len(indices[yr])))
        time[yr] = list(np.zeros(len(indices[yr])))
        #ratings[yr] = list(np.zeros(len(indices[yr])))
    with open(file) as infile:
        i = 0
        for line in infile:
            if i == idx[0]:
                idx.pop(0)
                x = json.loads(line)
                yr = x['reviewTime'][-4:]
                j = indices[yr].index(i)
                data[yr][j] = x.get('reviewText')
                time[yr][j] = x.get('reviewTime')
                #ratings[yr][j] = int(x.get('overall'))    
            i += 1
            if len(idx) == 0:
                break
    
    return data, time#, ratings


def rsquared(px, y):
    # fit values, and mean
    ybar = np.sum(y)/len(y)
    yhat = px
    ssres = np.sum((y - yhat)**2)
    sstot = np.sum((y - ybar)**2)
    
    return 1 - (ssres / sstot)


def plot_results(orig, pred, howmany, title1, title2, headline, savename, xrange=range(2010,2015), ylims=(0.79,0.88)):
    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10,5))

    ax1.plot([xrange for x in range(3)], orig, 'ro')
    ax1.plot([xrange for x in range(3)], pred, 'go')

    red_patch = mpatches.Patch(color='r', label='Original top/bot ' + str(howmany) + ' f.')
    green_patch = mpatches.Patch(color='g', label='Predicted top/bot ' + str(howmany) + ' f.')
    ax1.legend(handles=[red_patch, green_patch], fontsize='x-small', loc='upper right')

    ax1.ticklabel_format(useOffset=False, style='plain')
    ax1.xaxis.set_ticks(range(list(xrange)[0]-1,list(xrange)[-1]+2))
    ax1.set_ylim(ylims[0], ylims[1])

    ax1.set_xlabel('Tested on year')
    ax1.set_ylabel('Model accuracy')
    ax1.set_title(title1)


    ax2.plot(xrange, np.array(orig).mean(axis=0), 'ro')
    ax2.plot(xrange, np.array(pred).mean(axis=0), 'go')

    red_patch = mpatches.Patch(color='r', label='Original top/bot ' + str(howmany) + ' f.')
    green_patch = mpatches.Patch(color='g', label='Predicted top/bot ' + str(howmany) + ' f.')
    ax2.legend(handles=[red_patch, green_patch], fontsize='x-small', loc='upper right')

    ax2.ticklabel_format(useOffset=False, style='plain')
    ax2.xaxis.set_ticks(range(list(xrange)[0]-1,list(xrange)[-1]+2))
    ax2.set_ylim(ylims[0], ylims[1])

    ax2.set_xlabel('Tested on year')
    ax2.set_ylabel('Mean accuracy')
    ax2.set_title(title2)
    
    fig.subplots_adjust(top = 0.85)
    fig.suptitle(headline, fontsize=15, y=0.99)
   
    plt.savefig(savename + '.jpeg', dpi=300)
    plt.show()

    
def result_transform(results_original, results_predicted, loop):
    pred = []
    for i, m in enumerate(results_predicted[0]):
        pom = []
        for z in loop:
            pom.append(results_predicted[z][i])
        pred.append(pom)

    orig = []
    for i, m in enumerate(results_original[0]):
        pom = []
        for z in loop:
            pom.append(results_original[z][i])
        orig.append(pom)

    return np.array(orig).T, np.array(pred).T


def run_experiment_10_14(dataname, main, loop, HOWMANY, savestring, apendix):
    results = {}

    for z in loop:
        results[z] = []

        LR = LogisticRegression(penalty='l1', n_jobs=-1, solver='saga', max_iter=300)
        CV = CountVectorizer(ngram_range=(1,2), analyzer='word')

        x = sorted(main[z]['data'].keys())

        for i, key in enumerate(x[9:]):
            CV.fit(main[z]['top_' + str(HOWMANY) + dataname]+main[z]['bot_' + str(HOWMANY) + dataname])

            X_train = np.array(np.array(main[z]['data'][key]))[main[z]['train_idx'][int(key)-2000]]
            y_train = np.array(np.array(main[z]['ratings'][key]))[main[z]['train_idx'][int(key)-2000]]

            X_train = CV.transform(X_train)

            LR.fit(X_train,y_train)

            X_train = []
            y_train = []

            X_test = np.array(np.array(main[z]['data'][key]))[main[z]['test_idx'][int(key)-2000]]
            y_test = np.array(np.array(main[z]['ratings'][key]))[main[z]['test_idx'][int(key)-2000]]

            X_test = CV.transform(X_test)

            y_pred = LR.predict(X_test)

            l.save_file(savestring[z] + '/LR_predicted_' + str(HOWMANY) + 'top_' + str(HOWMANY) + 'bot_' + str(key) + '_' + str(apendix) + '.data', LR)

            results[z].append(LR.score(X_test, y_test))
            print(key + ': ', results[z][-1])
            X_test = []
            y_test = []
    return results

# %%
loadstring = []
loadstring.append('seed_1828_size_40000_topsize_300_date_2018-05-18')
loadstring.append('seed_16376_size_40000_topsize_300_date_2018-05-18')
loadstring.append('seed_23662_size_40000_topsize_300_date_2018-05-18')

loop = range(len(loadstring))

start_year = 2001
end_year = 2014

main = {}

for j, lstr in enumerate(loadstring):
    main[j] = {}

    main[j]['test_idx'] = {}
    for i, indx in enumerate(['/test_idx_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['test_idx'][i+1] = l.load_file(lstr + indx)

    main[j]['train_idx'] = {}
    for i, indx in enumerate(['/train_idx_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['train_idx'][i+1] = l.load_file(lstr + indx)

    main[j]['indices'] = l.load_file(lstr + '/indices.data')
    main[j]['ratings'] = l.load_file(lstr + '/ratings.data')

# %%
for z in loop:
    main[z]['data'], main[z]['time'] = load_previous_data(main[z]['indices'])
    #l.simplify_ratings(main[z]['data'], main[z]['ratings'])

# %%
savestring = []
savestring.append('seed_1828_size_40000_topsize_300_date_2018-05-18_BETTER')
savestring.append('seed_16376_size_40000_topsize_300_date_2018-05-18_BETTER')
savestring.append('seed_23662_size_40000_topsize_300_date_2018-05-18_BETTER')

loadstring = []
loadstring.append('seed_1828_size_40000_topsize_300_date_2018-05-18_all_in_CV')
loadstring.append('seed_16376_size_40000_topsize_300_date_2018-05-18_all_in_CV')
loadstring.append('seed_23662_size_40000_topsize_300_date_2018-05-18_all_in_CV')

for each in savestring:
    if not os.path.exists(each):
        os.makedirs(each)

# %%
x = sorted(main[z]['data'].keys())
z = 0
results = {}

# %%
### Load CV and LR

for j, lstr in enumerate(loadstring):
    main[j]['models'] = {}
    for i, model in enumerate(['/LR_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['models'][i+1] = l.load_file(lstr + model)
        
    main[j]['CV'] = l.load_file(lstr + '/CV.data')

### CONSTRUCT top_f and bot_f

x = sorted(main[z]['data'].keys())

for z in loop:
    main[z]['features'] = list(main[z]['CV'].get_feature_names())
    '''main[z]['top_f'] = {}
    main[z]['bot_f'] = {}
    
    for i, key in enumerate(x):
        if i == 0:
            main[z]['top_f'] = [[t,[len(main[z]['features'])-k]] for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:(-201):-1]
            main[z]['bot_f'] = [[t,[k+1]] for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:200]
        else:
            for j, m in enumerate(main[z]['top_f']):
                main[z]['top_f'][j][1] += [len(main[z]['features'])-k for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0],main[z]['features']))) if t == m[0]]
            for j, m in enumerate(main[z]['bot_f']):    
                main[z]['bot_f'][j][1] += [k+1 for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0],main[z]['features']))) if t == m[0]]'''

# %%
print(sorted(main[z].keys()))
# Out:
# ['CV', 'bot_200_MRR_mean_diff', 'bot_200_MRR_original', 'bot_200_features', 'bot_slopes', 'bot_slopes_200_MRR', 'bots', 'data', 'features', 'indices', 'models', 'ratings', 'test_idx', 'time', 'top_200_MRR_mean_diff', 'top_200_MRR_original', 'top_200_features', 'top_slopes', 'top_slopes_200_MRR', 'tops', 'train_idx']

# %%
for z in loop:
    for each in list(main[z].keys()):
        if each not in ['CV', 'data', 'features', 'indices', 'models', 'ratings', 'test_idx', 'time', 'train_idx']:
            main[z].pop(each, None)

# %%
print(sorted(main[z].keys()))
# Out:
# ['CV', 'data', 'features', 'indices', 'models', 'ratings', 'test_idx', 'time', 'train_idx']

# %%
#HOWMANY = 100
#HOWMANY3 = 300

#HOWMANY = 200
#HOWMANY3 = 600

HOWMANY = 400
HOWMANY3 = 1200

# %%
for z in loop:
    
    # TOP
    main[z]['tops'] = {}
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']), reverse=True)):
            main[z]['tops'][t] = []
            if i >= HOWMANY:
                break
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']), reverse=True)):
            if not main[z]['tops'].get(t) is None:
                if i + 1 > HOWMANY3:
                    k = HOWMANY3
                else:
                    k = i + 1
                main[z]['tops'][t].append(k)
    main[z]['top_slopes'] = []
    temp = []
    for key, values in main[z]['tops'].items():
        main[z]['top_slopes'].append([key, values])
        temp.append(sum(values))
    main[z]['top_slopes'] = [y for (t,y) in sorted(zip(temp, main[z]['top_slopes']))]

    # BOT
    main[z]['bots'] = {}
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']))):
            main[z]['bots'][t] = []
            if i >= HOWMANY:
                break
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']))):
            if not main[z]['bots'].get(t) is None:
                if i + 1 > HOWMANY3:
                    k = HOWMANY3
                else:
                    k = i + 1
                main[z]['bots'][t].append(k)
    main[z]['bot_slopes'] = []
    temp = []
    for key, values in main[z]['bots'].items():
        main[z]['bot_slopes'].append([key, values])
        temp.append(sum(values))
    main[z]['bot_slopes'] = [y for (t,y) in sorted(zip(temp, main[z]['bot_slopes']))]

print(main[0]['top_slopes'][:2])
print()
print(main[0]['bot_slopes'][:2])
# Out:
# [['excellent', [3, 4, 4, 4, 3, 3, 1, 2, 3, 5, 5, 5, 4, 10]], ['great', [8, 16, 24, 5, 1, 1, 2, 1, 1, 1, 1, 1, 1, 1]]]
#
# [['waste', [2, 3, 6, 1, 5, 6, 6, 4, 4, 6, 4, 4, 4, 8]], ['disappointed', [12, 8, 30, 7, 18, 8, 2, 6, 1, 1, 2, 1, 1, 4]]]

# %% [markdown]
# # Standard top and bot MRR

# %%
# Get top 100 and bot 100 features

for z in loop:
    main[z]['top_' + str(HOWMANY) + '_features'] = {}
    main[z]['bot_' + str(HOWMANY) + '_features'] = {}
    
    for i, key in enumerate(x):
        main[z]['top_' + str(HOWMANY) + '_features'][i+1] = [t for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:(-HOWMANY-1):-1]
        main[z]['bot_' + str(HOWMANY) + '_features'][i+1] = [t for k, (_,t) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:HOWMANY]

# Get top 100 and bot 100 feature MRR slopes based on years 01 - 08
for z in loop:
    main[z]['top_slopes_' + str(HOWMANY) + '_MRR'] = []
    temp = []
    for key, values in main[z]['tops'].items():
        main[z]['top_slopes_' + str(HOWMANY) + '_MRR'].append([key, values[:8]])
        temp.append(sum(values[:8]))
    main[z]['top_slopes_' + str(HOWMANY) + '_MRR'] = [y for (t,y) in sorted(zip(temp, main[z]['top_slopes_' + str(HOWMANY) + '_MRR']))]
    
for z in loop:
    main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'] = []
    temp = []
    for key, values in main[z]['bots'].items():
        main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'].append([key, values[:8]])
        temp.append(sum(values[:8]))
    main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'] = [y for (t,y) in sorted(zip(temp, main[z]['bot_slopes_' + str(HOWMANY) + '_MRR']))]

for z in loop:
    main[z]['top_' + str(HOWMANY) + '_MRR_original'] = [k for (k,t) in main[z]['top_slopes_' + str(HOWMANY) + '_MRR']][:HOWMANY]
    main[z]['bot_' + str(HOWMANY) + '_MRR_original'] = [k for (k,t) in main[z]['bot_slopes_' + str(HOWMANY) + '_MRR']][:HOWMANY]

# %% [markdown]
# # Predicting slopes using difference: mean(06-08) - mean(01-03)

# %%
# Predicting slopes using mean(06-08) - mean(01-03)

for z in loop:
    
    ######    TOP   #######
    stack = main[z]['top_slopes_' + str(HOWMANY) + '_MRR'][HOWMANY:HOWMANY3]
    next_best = []
    throwaway = []
    pom = np.array([t for (q,t) in stack])
    temp = []
    for i, vals in enumerate(pom):
        means = [np.round(np.mean(vals[:3]), 0), np.round(np.mean(vals[-3:]), 0)]
        if means[0] > HOWMANY and means[1] < HOWMANY and abs(means[0]-means[1])/means[0] > 0.05:
                next_best.append([stack[i][0], means[1]])
                temp.append(means[1])
    next_best  = [y for (t,y) in sorted(zip(temp, next_best))]

    main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff'] = []   
    stack = main[z]['top_slopes_' + str(HOWMANY) + '_MRR'][:HOWMANY]
    pom = np.array([t for (q,t) in stack])
    temp = []
    for i, vals in enumerate(pom):
        means = [np.round(np.mean(vals[:3]), 0), np.round(np.mean(vals[-3:]), 0)]
        if means[0] < HOWMANY and means[1] > HOWMANY and abs(means[0]-means[1])/means[0] > 0.05 and next_best:
            throwaway.append(stack[i][0])
            temp.append(next_best[0][1])
            main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff'].append(next_best.pop(0))
        else:
            main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff'].append([stack[i][0], means[1]])
            temp.append(means[1])
    main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff']  = [y[0] for (t,y) in sorted(zip(temp, main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff']))]
    
    
    ######    BOT   #######
    stack = main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'][HOWMANY:HOWMANY3]
    next_best = []
    throwaway = []
    pom = np.array([t for (q,t) in stack])
    temp = []
    for i, vals in enumerate(pom):
        means = [np.round(np.mean(vals[:3]), 0), np.round(np.mean(vals[-3:]), 0)]
        if means[0] > HOWMANY and means[1] < HOWMANY and abs(means[0]-means[1])/means[0] > 0.05:
                next_best.append([stack[i][0], means[1]])
                temp.append(means[1])
    next_best  = [y for (t,y) in sorted(zip(temp, next_best))]

    main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff'] = []   
    stack = main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'][:HOWMANY]
    pom = np.array([t for (q,t) in stack])
    temp = []
    for i, vals in enumerate(pom):
        means = [np.round(np.mean(vals[:3]), 0), np.round(np.mean(vals[-3:]), 0)]
        if means[0] < HOWMANY and means[1] > HOWMANY and abs(means[0]-means[1])/means[0] > 0.05 and next_best:
            throwaway.append(stack[i][0])
            temp.append(next_best[0][1])
            main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff'].append(next_best.pop(0))
        else:
            main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff'].append([stack[i][0], means[1]])
            temp.append(means[1])
    main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff']  = [y[0] for (t,y) in sorted(zip(temp, main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff']))]


##### PRINT difference form original
for z in loop:
    print(len(list(set(main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff']).intersection(set(main[z]['top_' + str(HOWMANY) + '_MRR_original'])))), end='  ')

print()

for z in loop:
    print(len(list(set(main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff']).intersection(set(main[z]['bot_' + str(HOWMANY) + '_MRR_original'])))), end='  ')

print()

for z in loop:
    print(len(main[z]['top_' + str(HOWMANY) + '_MRR_mean_diff']), end=' ')
    print(len(main[z]['bot_' + str(HOWMANY) + '_MRR_mean_diff']), end=' ')
# Out:
# 380  381  376
# 381  386  392
# 400 400 400 400 400 400

# %%
if not results.get('_MRR_original'):
    results['_MRR_original'] = {}

results['_MRR_original'][HOWMANY] = run_experiment_10_14('_MRR_original', main, loop, HOWMANY, savestring, apendix='_MRR_original')
# Out:
# D:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2010:  0.835125
# 2011:  0.837125
# 2012:  0.85525
# 2013:  0.864125
# 2014:  0.864375
# 2010:  0.853875
# 2011:  0.832625
# 2012:  0.851375
# 2013:  0.871
# 2014:  0.860125
# 2010:  0.852125
# 2011:  0.84325
# 2012:  0.843125
# 2013:  0.8465
# 2014:  0.866625

# %%
if not results.get('_MRR_mean_diff'):
    results['_MRR_mean_diff'] = {}

results['_MRR_mean_diff'][HOWMANY] = run_experiment_10_14('_MRR_mean_diff', main, loop, HOWMANY, savestring, apendix='_MRR_mean_diff')
# Out:
# D:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2010:  0.8345
# 2011:  0.836375
# 2012:  0.85675
# 2013:  0.864125
# 2014:  0.86275
# 2010:  0.853625
# 2011:  0.83375
# 2012:  0.8505
# 2013:  0.87
# 2014:  0.8595
# 2010:  0.85275
# 2011:  0.844
# 2012:  0.841625
# 2013:  0.847875
# 2014:  0.866125

# %%
orig, pred = result_transform(results['_MRR_original'][HOWMANY], results['_MRR_mean_diff'][HOWMANY], loop)

# %%
plot_results(orig, pred, HOWMANY,
             'Accuracy difference',
             'Mean accuracy difference',
             'Model accuracies: ' + str(2*HOWMANY) + ' most polar features from 01-08 (Rank, difference of means)',
             'Acc_diff_composite_' + str(2*HOWMANY) + '_rank_mean_diff')

# %%
results
# Out:
# {'_MRR_mean_diff': {100: {0: [0.826875, 0.828625, 0.84175, 0.8475, 0.8485],
#    1: [0.83525, 0.816875, 0.839625, 0.852125, 0.8495],
#    2: [0.839, 0.82875, 0.8355, 0.841125, 0.85325]},
#   200: {0: [0.828, 0.833875, 0.85, 0.8585, 0.8605],
#    1: [0.840625, 0.82775, 0.846125, 0.863375, 0.855625],
#    2: [0.8435, 0.839125, 0.836875, 0.844125, 0.861875]},
#   400: {0: [0.8345, 0.836375, 0.85675, 0.864125, 0.86275],
#    1: [0.853625, 0.83375, 0.8505, 0.87, 0.8595],
#    2: [0.85275, 0.844, 0.841625, 0.847875, 0.866125]}},
#  '_MRR_original': {100: {0: [0.82325, 0.825625, 0.8425, 0.852, 0.851],
#    1: [0.833375, 0.817625, 0.834625, 0.847625, 0.847],
#    2: [0.834375, 0.82475, 0.83375, 0.836375, 0.844625]},
#   200: {0: [0.826125, 0.827375, 0.8465, 0.857375, 0.855625],
#    1: [0.841375, 0.824875, 0.845, 0.863375, 0.85475],
#    2: [0.843, 0.8345, 0.833125, 0.844125, 0.858875]},
#   400: {0: [0.835125, 0.837125, 0.85525, 0.864125, 0.864375],
#    1: [0.853875, 0.832625, 0.851375, 0.871, 0.860125],
#    2: [0.852125, 0.84325, 0.843125, 0.8465, 0.866625]}}}

# %% [markdown]
# # Predicting slopes using linregress with pval < 0.05

# %%
#HOWMANY = 100
#HOWMANY3 = 300

#HOWMANY = 200
#HOWMANY3 = 600

HOWMANY = 400
HOWMANY3 = 1200

# %%
# Predicting slopes using linregress with pval < 0.05

for z in loop:
    ######    TOP   #######
    stack = main[z]['top_slopes_' + str(HOWMANY) + '_MRR'][HOWMANY:HOWMANY3]
    next_best = []
    throwaway = []
    pom = np.array([t for (q,t) in stack])
    ex = range(1, len(pom[0])+1)
    temp = []
    for i, vals in enumerate(pom):
        m, c, _, pval, _ = linregress(ex, vals)
        if pval < 0.05 and m < 0:
            vect = [int(m*t + c) for t in range(10, 15)]
            if np.mean(vect) < HOWMANY:
                next_best.append([stack[i][0], vect])
                temp.append(sum(vect))
    next_best  = [y for (t,y) in sorted(zip(temp, next_best))]

    main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress'] = []   
    stack = main[z]['top_slopes_' + str(HOWMANY) + '_MRR'][:HOWMANY]
    pom = np.array([t for (q,t) in stack])
    ex = range(1, len(pom[0])+1)
    temp = []
    for i, vals in enumerate(pom):
        m, c, _, pval, _ = linregress(ex, vals)
        vect = [int(m*t + c) for t in range(10, 15)]
        if pval < 0.05 and m > 0 and np.mean(vect) > HOWMANY and next_best:
            throwaway.append(stack[i][0])
            temp.append(sum(next_best[0][1]))
            main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress'].append(next_best.pop(0))
        else:
            main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress'].append([stack[i][0], vect])
            temp.append(sum(vect))
    main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress']  = [y[0] for (t,y) in sorted(zip(temp, main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress']))]
    
    
    ######    BOT   #######
    
    stack = main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'][HOWMANY:HOWMANY3]
    next_best = []
    throwaway = []
    pom = np.array([t for (q,t) in stack])
    ex = range(1, len(pom[0])+1)
    temp = []
    for i, vals in enumerate(pom):
        m, c, _, pval, _ = linregress(ex, vals)
        if pval < 0.05 and m < 0:
            vect = [int(m*t + c) for t in range(10, 15)]
            if np.mean(vect) < HOWMANY:
                next_best.append([stack[i][0], vect])
                temp.append(sum(vect))
    next_best  = [y for (t,y) in sorted(zip(temp, next_best))]

    main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress'] = []   
    stack = main[z]['bot_slopes_' + str(HOWMANY) + '_MRR'][:HOWMANY]
    pom = np.array([t for (q,t) in stack])
    ex = range(1, len(pom[0])+1)
    temp = []
    for i, vals in enumerate(pom):
        m, c, _, pval, _ = linregress(ex, vals)
        vect = [int(m*t + c) for t in range(10, 15)]
        if pval < 0.05 and m > 0 and np.mean(vect) > HOWMANY and next_best:
            throwaway.append(stack[i][0])
            temp.append(sum(next_best[0][1]))
            main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress'].append(next_best.pop(0))
        else:
            main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress'].append([stack[i][0], vect])
            temp.append(sum(vect))
    main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress']  = [y[0] for (t,y) in sorted(zip(temp, main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress']))]
    
for z in loop:
    print(len(list(set(main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress']).intersection(set(main[z]['top_' + str(HOWMANY) + '_MRR_original'])))), end='  ')

print()

for z in loop:
    print(len(list(set(main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress']).intersection(set(main[z]['bot_' + str(HOWMANY) + '_MRR_original'])))), end='  ')

print()

for z in loop:
    print(len(main[z]['top_' + str(HOWMANY) + '_MRR_pval_linregress']), end=' ')
    print(len(main[z]['bot_' + str(HOWMANY) + '_MRR_pval_linregress']), end=' ')
# Out:
# 373  375  377
# 381  380  384
# 400 400 400 400 400 400

# %%
if not results.get('_MRR_original'):
    results['_MRR_original'] = {}
results['_MRR_original'][HOWMANY] = run_experiment_10_14('_MRR_original', main, loop, HOWMANY, savestring, apendix='_MRR_original')
# Out:
# D:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2010:  0.835125
# 2011:  0.837125
# 2012:  0.85525
# 2013:  0.864125
# 2014:  0.86425
# 2010:  0.853875
# 2011:  0.832625
# 2012:  0.851375
# 2013:  0.871
# 2014:  0.860125
# 2010:  0.8525
# 2011:  0.843
# 2012:  0.843125
# 2013:  0.8465
# 2014:  0.866875

# %%
if not results.get('_MRR_pval_linregress'):
    results['_MRR_pval_linregress'] = {}
results['_MRR_pval_linregress'][HOWMANY] = run_experiment_10_14('_MRR_pval_linregress', main, loop, HOWMANY, savestring, apendix='_MRR_pval_linregress')
# Out:
# D:\Programs\Anaconda\lib\site-packages\sklearn\linear_model\sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# 2010:  0.837125
# 2011:  0.838
# 2012:  0.855875
# 2013:  0.8645
# 2014:  0.862625
# 2010:  0.853
# 2011:  0.83425
# 2012:  0.851125
# 2013:  0.8725
# 2014:  0.86075
# 2010:  0.850875
# 2011:  0.8445
# 2012:  0.842875
# 2013:  0.847875
# 2014:  0.86575

# %%
orig, pred = result_transform(results['_MRR_original'][HOWMANY], results['_MRR_pval_linregress'][HOWMANY], loop)

# %%
plot_results(orig, pred, HOWMANY,
             'Accuracy difference',
             'Mean accuracy difference',
             'Model accuracies: ' + str(2*HOWMANY) + ' most polar features from 01-08 (Rank, pval+linregress)',
             'Acc_diff_composite_' + str(2*HOWMANY) + '_rank_pval_linregress')

# %%
# original MRR

{0: [0.825875, 0.828375, 0.848625, 0.853625, 0.856125],
 1: [0.830875, 0.81525, 0.837, 0.84675, 0.850625],
 2: [0.836, 0.829375, 0.8255, 0.84025, 0.847875]}

# predicted MRR

{0: [0.82875, 0.830125, 0.85, 0.851375, 0.858875],
 1: [0.827375, 0.8155, 0.836625, 0.8485, 0.853],
 2: [0.8355, 0.82575, 0.83075, 0.8375, 0.855625]}
# Out:
# {0: [0.82875, 0.830125, 0.85, 0.851375, 0.858875],
#  1: [0.827375, 0.8155, 0.836625, 0.8485, 0.853],
#  2: [0.8355, 0.82575, 0.83075, 0.8375, 0.855625]}

# %% [markdown]
# # COEF

# %%
min_max_scaler = preprocessing.MinMaxScaler()
for z in loop:
    main[z]['top_' + str(HOWMANY) + '_coef'] = {}
    main[z]['bot_' + str(HOWMANY) + '_coef'] = {}
    main[z]['top_' + str(HOWMANY) + '_coef_scaler'] = {}
    main[z]['bot_' + str(HOWMANY) + '_coef_scaler'] = {}
    
    for i, key in enumerate(x):        
        main[z]['top_' + str(HOWMANY) + '_coef'][i+1] = min_max_scaler.fit_transform(np.array([r for k, (r,_) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:(-HOWMANY-1):-1]).reshape(HOWMANY,1))
        main[z]['top_' + str(HOWMANY) + '_coef_scaler'][i+1] = min_max_scaler

        main[z]['bot_' + str(HOWMANY) + '_coef'][i+1] = min_max_scaler.fit_transform(np.array([r for k, (r,_) in enumerate(sorted(zip(main[z]['models'][i+1].coef_[0], main[z]['features'])))][:HOWMANY]).reshape(HOWMANY,1))
        main[z]['bot_' + str(HOWMANY) + '_coef_scaler'][i+1] = min_max_scaler

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

for z in loop:
    for i in range(8):
        ax1.plot(main[z]['top_' + str(HOWMANY) + '_coef'][i+1])   
ax1.set_title('Coeficients of bot ' + str(HOWMANY) + ' features (MinMax scaled)')
ax1.set_xticks([1] + list(range(10,HOWMANY, 10)))
ax1.set_ylim(0,1)

for z in loop:
    for i in range(8):
        ax2.plot(main[z]['bot_' + str(HOWMANY) + '_coef'][i+1])    
ax2.set_title('Coeficients of bot ' + str(HOWMANY) + ' features (MinMax scaled)')
ax2.set_xticks([1] + list(range(10,HOWMANY, 10)))
ax2.set_ylim(0,1)

fig.text(0.5, 0.001, 'Feature rank', ha='center')
fig.text(0.001, 0.5, 'Coeficient (MinMax scaled)', va='center', rotation='vertical')

fig.tight_layout()
plt.savefig('Coeficients_of_top_and_bot_' + str(HOWMANY) + '_features_(MinMax_scaled).jpeg', dpi=300)
plt.show()

# %%
min_max_scaler = preprocessing.MinMaxScaler((0,1))

fig, (ax1, ax2, ax3) = plt.subplots(3, 1,figsize=(10,10))

z = 0
for i in range(8):
    pom = sorted(min_max_scaler.fit_transform(np.array(main[z]['models'][i+1].coef_[0]).reshape(len(main[z]['models'][i+1].coef_[0]),1)))
    ax1.plot(np.array(range(0,HOWMANY)), np.array(pom[:HOWMANY]), color='r')
    ax1.plot(np.array(range(HOWMANY,2*HOWMANY)), np.array(pom[-HOWMANY:]), color='b')
#ax1.set_title('Coeficients of all features (MinMax scaled)')
ax1.set_ylim(0,1)

z = 1
for i in range(8):
    pom = sorted(min_max_scaler.fit_transform(np.array(main[z]['models'][i+1].coef_[0]).reshape(len(main[z]['models'][i+1].coef_[0]),1)))
    ax2.plot(np.array(range(0,HOWMANY)), np.array(pom[:HOWMANY]), color='r')
    ax2.plot(np.array(range(HOWMANY,2*HOWMANY)), np.array(pom[-HOWMANY:]), color='b')
ax2.set_ylim(0,1)

z = 0
for i in range(8):
    pom = sorted(min_max_scaler.fit_transform(np.array(main[z]['models'][i+1].coef_[0]).reshape(len(main[z]['models'][i+1].coef_[0]),1)))
    ax3.plot(np.array(range(0,HOWMANY)), np.array(pom[:HOWMANY]), color='r')
    ax3.plot(np.array(range(HOWMANY,2*HOWMANY)), np.array(pom[-HOWMANY:]), color='b')
ax3.set_ylim(0,1)

fig.text(0.5, 0.001, 'Feature (sroted by coeficient)', ha='center')
fig.text(0.001, 0.5, 'Coeficient (MinMax scaled)', va='center', rotation='vertical')
plt.suptitle('Coeficients of top ' + str(HOWMANY) + ' and bot ' + str(HOWMANY) + ' features (MinMax scaled)', fontsize=20)

fig.tight_layout()
plt.subplots_adjust(top=0.9)
plt.savefig('Coeficients_of_top' + str(HOWMANY) + '_and_bot' + str(HOWMANY) + '_features_(MinMax_scaled).jpeg', dpi=300)
plt.show()

# %%
min_max_scaler = preprocessing.MinMaxScaler((0,1))

for z in loop:
    
    # TOP
    main[z]['tops_coef'] = {}    
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']), reverse=True)):
            main[z]['tops_coef'][t] = []
            if i >= HOWMANY:
                break
    for j, key in enumerate(x):
        for i, (r,t) in enumerate(sorted(zip(list(min_max_scaler.fit_transform(np.array(main[z]['models'][j+1].coef_[0]).reshape(-1,1)).reshape(-1,)), main[z]['features']), reverse=True)):
            if not main[z]['tops_coef'].get(t) is None:
                main[z]['tops_coef'][t].append(r)
    
    main[z]['top_slopes_coef'] = []
    temp = []
    for key, values in main[z]['tops_coef'].items():
        main[z]['top_slopes_coef'].append([key, values])
        temp.append(sum(values))
    main[z]['top_slopes_coef'] = [y for (t,y) in sorted(zip(temp, main[z]['top_slopes_coef']), reverse=True)]

    # BOT
    main[z]['bots_coef'] = {}
    for j, key in enumerate(x):
        for i, (_,t) in enumerate(sorted(zip(main[z]['models'][j+1].coef_[0], main[z]['features']))):
            main[z]['bots_coef'][t] = []
            if i >= HOWMANY:
                break
    for j, key in enumerate(x):
        for i, (r,t) in enumerate(sorted(zip(list(min_max_scaler.fit_transform(np.array(main[z]['models'][j+1].coef_[0]).reshape(-1,1)).reshape(-1,)), main[z]['features']))):
            if not main[z]['bots_coef'].get(t) is None:
                main[z]['bots_coef'][t].append(r)
    main[z]['bot_slopes_coef'] = []
    temp = []
    for key, values in main[z]['bots_coef'].items():
        main[z]['bot_slopes_coef'].append([key, values])
        temp.append(sum(values))
    main[z]['bot_slopes_coef'] = [y for (t,y) in sorted(zip(temp, main[z]['bot_slopes_coef']), reverse=True)]

print(main[0]['top_slopes_coef'][:2])
print()
print(main[0]['bot_slopes_coef'][:2])

# %%
# Get top 100 and bot 100 feature COEF slopes based on years 01 - 08
for z in loop:
    main[z]['top_slopes_' + str(HOWMANY) + '_coef'] = []
    temp = []
    for key, values in main[z]['tops_coef'].items():
        main[z]['top_slopes_' + str(HOWMANY) + '_coef'].append([key, values[:8]])
        temp.append(sum(values[:8]))
    main[z]['top_slopes_' + str(HOWMANY) + '_coef'] = [y for (t,y) in sorted(zip(temp, main[z]['top_slopes_' + str(HOWMANY) + '_coef']), reverse=True)]
    
for z in loop:
    main[z]['bot_slopes_' + str(HOWMANY) + '_coef'] = []
    temp = []
    for key, values in main[z]['bots_coef'].items():
        main[z]['bot_slopes_' + str(HOWMANY) + '_coef'].append([key, values[:8]])
        temp.append(sum(values[:8]))
    main[z]['bot_slopes_' + str(HOWMANY) + '_coef'] = [y for (t,y) in sorted(zip(temp, main[z]['bot_slopes_' + str(HOWMANY) + '_coef']), reverse=True)]

# %%
print(main[0]['top_slopes_' + str(HOWMANY) + '_coef'][:2])
print()
print(main[0]['bot_slopes_' + str(HOWMANY) + '_coef'][:2])

# %%
# Predicting slopes using LEAST SQUARES LINEAR FIT on COEF

for z in loop:
    main[z]['top_slopes_' + str(HOWMANY) + '_coef_predicted'] = []
    pom = np.array([t for (q,t) in main[z]['top_slopes_' + str(HOWMANY) + '_coef']])    
    x = range(len(pom[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    temp = []
    for i, vals in enumerate(pom):
        m, c = np.linalg.lstsq(A, vals, rcond=-1)[0]
        main[z]['top_slopes_' + str(HOWMANY) + '_coef_predicted'].append([main[z]['top_slopes_' + str(HOWMANY) + '_coef'][i][0], [m*t + c for t in range(10, 15)]])
        temp.append(sum([m*t + c for t in range(10, 15)]))
    main[z]['top_slopes_' + str(HOWMANY) + '_coef_predicted']  = [y for (t,y) in sorted(zip(temp, main[z]['top_slopes_' + str(HOWMANY) + '_coef_predicted']), reverse=True)]
    
    main[z]['bot_slopes_' + str(HOWMANY) + '_coef_predicted'] = []
    pom = np.array([t for (q,t) in main[z]['bot_slopes_' + str(HOWMANY) + '_coef']])    
    x = range(len(pom[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    temp = []
    for i, vals in enumerate(pom):
        m, c = np.linalg.lstsq(A, vals, rcond=-1)[0]
        main[z]['bot_slopes_' + str(HOWMANY) + '_coef_predicted'].append([main[z]['bot_slopes_' + str(HOWMANY) + '_coef'][i][0], [m*t + c for t in range(10, 15)]])
        temp.append(sum([m*t + c for t in range(10, 15)]))
    main[z]['bot_slopes_' + str(HOWMANY) + '_coef_predicted']  = [y for (t,y) in sorted(zip(temp, main[z]['bot_slopes_' + str(HOWMANY) + '_coef_predicted']), reverse=True)]

# %%
print(main[0]['top_slopes_' + str(HOWMANY) + '_coef_predicted'][:2])

# %%
print([x[0] for x in main[0]['top_slopes_' + str(HOWMANY) + '_coef_predicted'][:10]])
print([x[0] for x in main[0]['top_slopes_' + str(HOWMANY) + '_coef'][:10]])

# %%
for z in loop:
    main[z]['top_' + str(HOWMANY) + '_coef_original'] = [k for (k,t) in main[z]['top_slopes_' + str(HOWMANY) + '_coef']][:HOWMANY]
    main[z]['bot_' + str(HOWMANY) + '_coef_original'] = [k for (k,t) in main[z]['bot_slopes_' + str(HOWMANY) + '_coef']][:HOWMANY]
    main[z]['top_' + str(HOWMANY) + '_coef_predicted'] = [k for (k,t) in main[z]['top_slopes_' + str(HOWMANY) + '_coef_predicted']][:HOWMANY]
    main[z]['bot_' + str(HOWMANY) + '_coef_predicted'] = [k for (k,t) in main[z]['bot_slopes_' + str(HOWMANY) + '_coef_predicted']][:HOWMANY]

# %%
print(main[0]['top_' + str(HOWMANY) + '_coef_original'][:10])
print(main[0]['top_' + str(HOWMANY) + '_coef_predicted'][:10])

# %%
print(len(main[0]['bot_' + str(HOWMANY) + '_coef_original']))
print(len(main[0]['bot_' + str(HOWMANY) + '_coef_predicted']))
print(len(main[0]['top_' + str(HOWMANY) + '_coef_original']))
print(len(main[0]['top_' + str(HOWMANY) + '_coef_predicted']))
# Out:
# 400
# 400
# 400
# 400

# %%
# original COEF

{0: [0.80425, 0.805375, 0.820625, 0.834125, 0.838375],
 1: [0.806625, 0.7955, 0.821125, 0.829625, 0.833],
 2: [0.814875, 0.810625, 0.808875, 0.827875, 0.8345]}

# predicted COEF

{0: [0.801875, 0.80625, 0.822625, 0.834625, 0.837],
 1: [0.814875, 0.793375, 0.821125, 0.833375, 0.829375],
 2: [0.815875, 0.80925, 0.816875, 0.82475, 0.834]}

# %%
# Normal run 100top_100bot

{0: [0.865125,
  0.850125,
  0.852375,
  0.83175,
  0.80825,
  0.81875,
  0.845375,
  0.833,
  0.828625,
  0.8245,
  0.827,
  0.846125,
  0.854625,
  0.852875],
 1: [0.8605,
  0.84675,
  0.842375,
  0.832875,
  0.819875,
  0.83375,
  0.850875,
  0.84025,
  0.836625,
  0.834875,
  0.818375,
  0.84125,
  0.862375,
  0.8515],
 2: [0.85625,
  0.860375,
  0.8445,
  0.8325,
  0.813375,
  0.821375,
  0.853875,
  0.83725,
  0.8355,
  0.83975,
  0.83675,
  0.833875,
  0.844625,
  0.858625]}
# Out:
# {0: [0.865125,
#   0.850125,
#   0.852375,
#   0.83175,
#   0.80825,
#   0.81875,
#   0.845375,
#   0.833,
#   0.828625,
#   0.8245,
#   0.827,
#   0.846125,
#   0.854625,
#   0.852875],
#  1: [0.8605,
#   0.84675,
#   0.842375,
#   0.832875,
#   0.819875,
#   0.83375,
#   0.850875,
#   0.84025,
#   0.836625,
#   0.834875,
#   0.818375,
#   0.84125,
#   0.862375,
#   0.8515],
#  2: [0.85625,
#   0.860375,
#   0.8445,
#   0.8325,
#   0.813375,
#   0.821375,
#   0.853875,
#   0.83725,
#   0.8355,
#   0.83975,
#   0.83675,
#   0.833875,
#   0.844625,
#   0.858625]}

# %%
'''## PLOT POLYFIT

pom = np.array([t for (q,t) in main[z]['top_slopes_' + str(HOWMANY) + '_MRR']])
ex = range(len(pom[0]))

for each in pom:
    means = [np.mean(each[0:3]), np.mean(each[3:5]), np.mean(each[5:])]
    mex = range(len(means))
    
    m, c, rval, pval, stderr = linregress(ex, each)
    p = np.poly1d(np.polyfit(ex, each, 2))
    r2 = rsquared(p(ex), each)
    
    #mm, mc, mrval, mpval, mstderr = linregress(mex, means)
    mp = np.poly1d(np.polyfit(mex, means, 2))
    mr2 = rsquared(mp(mex), means)
    
    #if rval**2 > 0.75 and pval < 0.01 and r2 > 0.8:
    if pval < 0.05: #and r2 > 0.9:
        fig, (ax1, ax3, ax2) = plt.subplots(1, 3,figsize=(12,3))        
        
        m, c, rval, pval, stderr = linregress(ex, each)
        ax2.plot(ex, each, 'bo')
        ax2.plot(ex, m*ex + c, 'r')
        ax2.set_ylim(min(each)-1, max(each)+1)
        ax2.set_title('R**2: ' + str(np.round(rval**2, 4)) + '    p: ' + str(np.round(pval, 4)) + '    stderr: ' + str(np.round(stderr, 4)))
               
        ax1.plot(ex, each, 'bo')
        ax1.plot(ex, p(ex), 'r')
        ax1.set_ylim(min(each)-1, max(each)+1)
        ax1.set_title('R**2: ' + str(np.round(r2, 4)))
        
        ax3.plot(mex, means, 'bo')
        ax3.plot(np.linspace(0,2,8), mp(np.linspace(0,2,8)), 'r')
        #ax3.plot(mex, mm*mex + mc, 'r')
        ax3.set_ylim(min(each)-1, max(each)+1)
        ax3.set_title('R**2: ' + str(np.round(mr2, 4)))
        #ax3.set_title('R**2: ' + str(np.round(mrval**2, 4)) + '    p: ' + str(np.round(mpval, 4)) + '    stderr: ' + str(np.round(mstderr, 4)))
        
        plt.tight_layout()
        plt.show()'''
# Out:
# "## PLOT POLYFIT\n\npom = np.array([t for (q,t) in main[z]['top_slopes_' + str(HOWMANY) + '_MRR']])\nex = range(len(pom[0]))\n\nfor each in pom:\n    means = [np.mean(each[0:3]), np.mean(each[3:5]), np.mean(each[5:])]\n    mex = range(len(means))\n    \n    m, c, rval, pval, stderr = linregress(ex, each)\n    p = np.poly1d(np.polyfit(ex, each, 2))\n    r2 = rsquared(p(ex), each)\n    \n    #mm, mc, mrval, mpval, mstderr = linregress(mex, means)\n    mp = np.poly1d(np.polyfit(mex, means, 2))\n    mr2 = rsquared(mp(mex), means)\n    \n    #if rval**2 > 0.75 and pval < 0.01 and r2 > 0.8:\n    if pval < 0.05: #and r2 > 0.9:\n        fig, (ax1, ax3, ax2) = plt.subplots(1, 3,figsize=(12,3))        \n        \n        m, c, rval, pval, stderr = linregress(ex, each)\n        ax2.plot(ex, each, 'bo')\n        ax2.plot(ex, m*ex + c, 'r')\n        ax2.set_ylim(min(each)-1, max(each)+1)\n        ax2.set_title('R**2: ' + str(np.round(rval**2, 4)) + '    p: ' + str(np.round(pval, 4)) + '    stderr: ' + str(np.round(stderr, 4)))\n               \n        ax1.plot(ex, each, 'bo')\n        ax1.plot(ex, p(ex), 'r')\n        ax1.set_ylim(min(each)-1, max(each)+1)\n        ax1.set_title('R**2: ' + str(np.round(r2, 4)))\n        \n        ax3.plot(mex, means, 'bo')\n        ax3.plot(np.linspace(0,2,8), mp(np.linspace(0,2,8)), 'r')\n        #ax3.plot(mex, mm*mex + mc, 'r')\n        ax3.set_ylim(min(each)-1, max(each)+1)\n        ax3.set_title('R**2: ' + str(np.round(mr2, 4)))\n        #ax3.set_title('R**2: ' + str(np.round(mrval**2, 4)) + '    p: ' + str(np.round(mpval, 4)) + '    stderr: ' + str(np.round(mstderr, 4)))\n        \n        plt.tight_layout()\n        plt.show()"

# %%
## LOGISTIC REGRESSION STANDARD RUN


'''LR = LogisticRegression(penalty='l1', n_jobs=-1, solver='saga', max_iter=300)
CV = CountVectorizer(ngram_range=(1,2), analyzer='word', min_df=5, max_features=5000)'''


'''
def get_all_features(data, train_idx, CV):
    CV.fit(data[train_idx])
    return list(CV.get_feature_names())
    
multi_features = []

for i, key in enumerate(x):
    multi_features += get_all_features(np.array(main[z]['data'][key]), main[z]['train_idx'][i+1], CV)'''



'''multi_features = sorted(list(set(multi_features)))

CV = CountVectorizer(ngram_range=(1,2), analyzer='word')
CV.fit(multi_features)

l.save_file(savestring[z] + '/CV.data', CV)'''



'''results = []

for i, key in enumerate(x):
    X_train = np.array(np.array(main[z]['data'][key]))[main[z]['train_idx'][i+1]]
    y_train = np.array(np.array(main[z]['ratings'][key]))[main[z]['train_idx'][i+1]]
    
    X_train = CV.transform(X_train)
    
    LR.fit(X_train,y_train)
    
    X_train = []
    y_train = []
    
    X_test = np.array(np.array(main[z]['data'][key]))[main[z]['test_idx'][i+1]]
    y_test = np.array(np.array(main[z]['ratings'][key]))[main[z]['test_idx'][i+1]]
    
    X_test = CV.transform(X_test)
    
    y_pred = LR.predict(X_test)
    l.save_file(savestring[z] + '/LR_' + str(key) + '.data', LR)
    print(key)
    print(LR.score(X_test, y_test))
    print()
    
    X_test = []
    y_test = []'''

#multi_features = []
# Out:
# "results = []\n\nfor i, key in enumerate(x):\n    X_train = np.array(np.array(main[z]['data'][key]))[main[z]['train_idx'][i+1]]\n    y_train = np.array(np.array(main[z]['ratings'][key]))[main[z]['train_idx'][i+1]]\n    \n    X_train = CV.transform(X_train)\n    \n    LR.fit(X_train,y_train)\n    \n    X_train = []\n    y_train = []\n    \n    X_test = np.array(np.array(main[z]['data'][key]))[main[z]['test_idx'][i+1]]\n    y_test = np.array(np.array(main[z]['ratings'][key]))[main[z]['test_idx'][i+1]]\n    \n    X_test = CV.transform(X_test)\n    \n    y_pred = LR.predict(X_test)\n    l.save_file(savestring[z] + '/LR_' + str(key) + '.data', LR)\n    print(key)\n    print(LR.score(X_test, y_test))\n    print()\n    \n    X_test = []\n    y_test = []"

# %%
### OLD top 100 run

'''results = {}
for z in loop:
    results[z] =[]
    LR = LogisticRegression(penalty='l1', n_jobs=-1, solver='saga', max_iter=300)
    CV = CountVectorizer(ngram_range=(1,2), analyzer='word')

    x = sorted(main[z]['data'].keys())

    for i, key in enumerate(x):
        CV.fit(main[z]['top_100_features'][i+1]+main[z]['bot_100_features'][i+1])

        X_train = np.array(np.array(main[z]['data'][key]))[main[z]['train_idx'][i+1]]
        y_train = np.array(np.array(main[z]['ratings'][key]))[main[z]['train_idx'][i+1]]

        X_train = CV.transform(X_train)

        LR.fit(X_train,y_train)

        X_train = []
        y_train = []

        X_test = np.array(np.array(main[z]['data'][key]))[main[z]['test_idx'][i+1]]
        y_test = np.array(np.array(main[z]['ratings'][key]))[main[z]['test_idx'][i+1]]

        X_test = CV.transform(X_test)

        y_pred = LR.predict(X_test)
        l.save_file(savestring[z] + '/LR_100top_100bot_' + str(key) + '.data', LR)
        print(key)
        results[z].append(LR.score(X_test, y_test))
        print(results[z][-1])
        print()

        X_test = []
        y_test = []'''
# Out:
# "results = {}\nfor z in loop:\n    results[z] =[]\n    LR = LogisticRegression(penalty='l1', n_jobs=-1, solver='saga', max_iter=300)\n    CV = CountVectorizer(ngram_range=(1,2), analyzer='word')\n\n    x = sorted(main[z]['data'].keys())\n\n    for i, key in enumerate(x):\n        CV.fit(main[z]['top_100_features'][i+1]+main[z]['bot_100_features'][i+1])\n\n        X_train = np.array(np.array(main[z]['data'][key]))[main[z]['train_idx'][i+1]]\n        y_train = np.array(np.array(main[z]['ratings'][key]))[main[z]['train_idx'][i+1]]\n\n        X_train = CV.transform(X_train)\n\n        LR.fit(X_train,y_train)\n\n        X_train = []\n        y_train = []\n\n        X_test = np.array(np.array(main[z]['data'][key]))[main[z]['test_idx'][i+1]]\n        y_test = np.array(np.array(main[z]['ratings'][key]))[main[z]['test_idx'][i+1]]\n\n        X_test = CV.transform(X_test)\n\n        y_pred = LR.predict(X_test)\n        l.save_file(savestring[z] + '/LR_100top_100bot_' + str(key) + '.data', LR)\n        print(key)\n        results[z].append(LR.score(X_test, y_test))\n        print(results[z][-1])\n        print()\n\n        X_test = []\n        y_test = []"
