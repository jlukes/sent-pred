# %%
import library as l

import numpy as np
import pandas as pd
import copy
import matplotlib.pyplot as plt
import datetime
import os

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

from scipy.stats import linregress

# %%
loadstring = []
loadstring.append('seed_6676_size_40000_topsize_300_date_2018-04-23')
loadstring.append('seed_15320_size_40000_topsize_300_date_2018-05-04')
loadstring.append('seed_39729_size_40000_topsize_300_date_2018-05-04')

loop = range(len(loadstring))

start_year = 2001
end_year = 2014

main = {}

for j, lstr in enumerate(loadstring):
    main[j] = {}

    main[j]['models'] = {}
    for i, model in enumerate(['/LR_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['models'][i+1] = l.load_file(lstr + model)

    main[j]['test_idx'] = {}
    for i, indx in enumerate(['/test_idx_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['test_idx'][i+1] = l.load_file(lstr + indx)

    main[j]['train_idx'] = {}
    for i, indx in enumerate(['/train_idx_' + str(start_year+x) + '.data' for x in range(end_year - start_year + 1)]):
        main[j]['train_idx'][i+1] = l.load_file(lstr + indx)

    main[j]['top_f'] = l.load_file(lstr + '/top_f.data')
    main[j]['bot_f'] = l.load_file(lstr + '/top_f.data')
    main[j]['CV'] = l.load_file(lstr + '/CV_2001.data')
    main[j]['indices'] = l.load_file(lstr + '/indices.data')
    main[j]['ratings'] = l.load_file(lstr + '/ratings.data')
    main[j]['seen'] = l.load_file(lstr + '/seen.data')
    main[j]['features'] = list(main[j]['CV'].get_feature_names())

'''train_idx = l.load_file(lstr + '/train_idx.data')
test_idx = l.load_file(lstr + '/test_idx.data')'''
# Out:
# "train_idx = l.load_file(lstr + '/train_idx.data')\ntest_idx = l.load_file(lstr + '/test_idx.data')"

# %%
main[0]['top_f']
# Out:
# [['highly', [1, 4, 4, 1, 3, 3, 6, 3, 3, 5, 5, 9, 16, 14]],
#  ['amazing', [2, 1, 5, 4, 1, 8, 16, 6, 6, 21, 10, 17, 33, 12]],
#  ['awesome', [3, 9, 1, 5, 6, 25, 41, 23, 8, 36, 21, 15, 23, 5]],
#  ['excellent', [4, 2, 2, 2, 2, 2, 2, 1, 1, 3, 6, 6, 15, 4]],
#  ['not only', [5, 5, 9, 10, 10, 22, 36, 16, 28, 64, 50, 91, 159, 56]],
#  ['wonderful', [6, 3, 3, 3, 5, 4, 5, 5, 5, 13, 19, 20, 25, 13]],
#  ['perfect', [7, 7, 45, 7, 7, 14, 7, 4, 4, 6, 3, 3, 6, 2]],
#  ['is must', [8, 13, 20, 20, 32, 51, 47, 45, 33, 113, 100, 152, 270, 449]],
#  ['incredible',
#   [9, 10, 57, 40, 50, 173, 137, 126, 130, 218, 487, 373, 787, 619]],
#  ['beautiful', [10, 8, 39, 12, 60, 23, 18, 40, 51, 34, 37, 39, 53, 36]],
#  ['great', [11, 11, 6, 6, 4, 1, 1, 2, 2, 1, 1, 1, 1, 1]],
#  ['loved', [12, 18, 26, 18, 16, 19, 13, 17, 16, 15, 25, 12, 10, 9]],
#  ['favorite', [13, 33, 78, 17, 30, 28, 33, 28, 54, 44, 55, 52, 97, 43]],
#  ['must', [14, 36, 37, 9, 28, 37, 40, 18, 48, 51, 45, 43, 62, 62]],
# ...

# %%
for z in loop:
    main[z]['tops'] = {}
    for j in range(1,15):
        for i, (_,x) in enumerate(sorted(zip(main[z]['models'][j].coef_[0], main[z]['features']), reverse=True)):
            main[z]['tops'][x] = []
            if i >= 300:
                break
    for j in range(1,15):
        for i, (_,x) in enumerate(sorted(zip(main[z]['models'][j].coef_[0], main[z]['features']), reverse=True)):
            if not main[z]['tops'].get(x) is None:
                if i + 1 > 1500:
                    k = 1500
                else:
                    k = i + 1
                main[z]['tops'][x].append(k)

    main[z]['bots'] = {}
    for j in range(1,15):
        for i, (_,x) in enumerate(sorted(zip(main[z]['models'][j].coef_[0], main[z]['features']))):
            main[z]['bots'][x] = []
            if i >= 300:
                break
    for j in range(1,15):
        for i, (_,x) in enumerate(sorted(zip(main[z]['models'][j].coef_[0], main[z]['features']))):
            if not main[z]['bots'].get(x) is None:
                if i + 1 > 1500:
                    k = 1500
                else:
                    k = i + 1
                main[z]['bots'][x].append(k)

# %%
len(main[0]['bots'])
# Out:
# 1165

# %%
for z in loop:
    main[z]['top_slopes'] = []
    temp = []
    for key, values in main[z]['tops'].items():
        main[z]['top_slopes'].append([key, values])
        temp.append(sum(values))
    main[z]['top_slopes'] = [y for (x,y) in sorted(zip(temp, main[z]['top_slopes']))]
    
for z in loop:
    main[z]['bot_slopes'] = []
    temp = []
    for key, values in main[z]['bots'].items():
        main[z]['bot_slopes'].append([key, values])
        temp.append(sum(values))
    main[z]['bot_slopes'] = [y for (x,y) in sorted(zip(temp, main[z]['bot_slopes']))]

# %%
for z in loop:
    print(main[z]['top_slopes'][0])
print()
for z in loop:
    print(main[z]['bot_slopes'][0])
# Out:
# ['great', [11, 11, 6, 6, 4, 1, 1, 2, 2, 1, 1, 1, 1, 1]]
# ['great', [7, 2, 9, 4, 1, 3, 1, 2, 1, 1, 1, 1, 1, 1]]
# ['excellent', [1, 2, 6, 1, 2, 2, 2, 2, 3, 3, 4, 3, 4, 7]]
#
# ['disappointed', [3, 6, 2, 6, 6, 6, 1, 2, 2, 1, 1, 1, 10, 1]]
# ['disappointed', [6, 7, 6, 6, 11, 7, 1, 2, 3, 3, 1, 3, 1, 4]]
# ['waste', [4, 4, 6, 2, 7, 3, 3, 3, 4, 8, 2, 3, 4, 8]]

# %%
top_slopes = []

temp = []
for z in loop:
    temp.append(set([x[0] for x in main[z]['top_slopes']]))
temp = list(set.intersection(*temp))
indx = {}

for z in loop:
    for i, m in enumerate(main[z]['top_slopes']):
        if m[0] in temp:
            if z == 0:
                top_slopes.append([m[0], [m[1]]])
                indx[m[0]] = len(top_slopes)-1
            else:
                top_slopes[indx.get(m[0])][1].append(m[1])
temp = [sum(x[1][0] + x[1][1] + x[1][2]) for x in top_slopes]
top_slopes = [y for (x,y) in sorted(zip(temp, top_slopes))]
#print(top_slopes)

bot_slopes = []
temp = []
for z in loop:
    temp.append(set([x[0] for x in main[z]['bot_slopes']]))
temp = list(set.intersection(*temp))
indx = {}

for z in loop:
    for i, m in enumerate(main[z]['bot_slopes']):
        if m[0] in temp:
            if z == 0:
                bot_slopes.append([m[0], [m[1]]])
                indx[m[0]] = len(bot_slopes)-1
            else:
                bot_slopes[indx.get(m[0])][1].append(m[1])
temp = [sum(x[1][0] + x[1][1] + x[1][2]) for x in bot_slopes]
bot_slopes = [y for (x,y) in sorted(zip(temp, bot_slopes))]
#print(bot_slopes)

# %%
for z in loop:
    print(main[z]['top_slopes'][:10])
    print()
# Out:
# [['great', [11, 11, 6, 6, 4, 1, 1, 2, 2, 1, 1, 1, 1, 1]], ['excellent', [4, 2, 2, 2, 2, 2, 2, 1, 1, 3, 6, 6, 15, 4]], ['highly', [1, 4, 4, 1, 3, 3, 6, 3, 3, 5, 5, 9, 16, 14]], ['perfect', [7, 7, 45, 7, 7, 14, 7, 4, 4, 6, 3, 3, 6, 2]], ['wonderful', [6, 3, 3, 3, 5, 4, 5, 5, 5, 13, 19, 20, 25, 13]], ['amazing', [2, 1, 5, 4, 1, 8, 16, 6, 6, 21, 10, 17, 33, 12]], ['the best', [16, 6, 12, 8, 13, 7, 11, 9, 15, 11, 9, 19, 19, 28]], ['awesome', [3, 9, 1, 5, 6, 25, 41, 23, 8, 36, 21, 15, 23, 5]], ['loved', [12, 18, 26, 18, 16, 19, 13, 17, 16, 15, 25, 12, 10, 9]], ['highly recommend', [15, 15, 46, 13, 11, 16, 22, 11, 14, 19, 18, 27, 39, 42]]]
#
# ...

# %%
col = ['b', 'g', 'r']

j = 0
for i in range(100):#len(top_slopes)):
    temp = top_slopes[i][1]
    x = range(len(temp[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    y = []
    m = [*loop]
    c = [*loop]
    for z in loop: 
        y.append(temp[z])
        m[z], c[z] = np.linalg.lstsq(A, y[z])[0]
    if all(slope > 10 for slope in m):
        if j == 0:
            fig = plt.figure() #figsize = (10,500)
            ax = fig.add_subplot(111)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(top_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        else:
            for k in range(j):
                fig.axes[k].change_geometry(j+1, 1, k+1)
            ax = fig.add_subplot(j+1, 1, j+1)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(top_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        j += 1

#plt.subplots_adjust(hspace=0.25)
fig.set_size_inches(10, 2*j, forward=True)
fig.tight_layout()
fig.suptitle('Mean reciprocal rank positivity degradation from 01 - 14', fontsize=20)
plt.subplots_adjust(top=(j-1)/j)
plt.savefig('MRR_positivity_degradation.jpeg', dpi=300)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\ipykernel\__main__.py:13: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
j = 0
for i in range(100):#len(top_slopes)):
    temp = top_slopes[i][1]
    x = range(len(temp[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    y = []
    m = [*loop]
    c = [*loop]
    for z in loop: 
        y.append(temp[z])
        m[z], c[z] = np.linalg.lstsq(A, y[z])[0]
    if all(slope < -10 for slope in m):
        if j == 0:
            fig = plt.figure() #figsize = (10,500)
            ax = fig.add_subplot(111)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(top_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        else:
            for k in range(j):
                fig.axes[k].change_geometry(j+1, 1, k+1)
            ax = fig.add_subplot(j+1, 1, j+1)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(top_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        j += 1

#plt.subplots_adjust(hspace=0.25)
fig.set_size_inches(10, 2*j, forward=True)
fig.tight_layout()
fig.suptitle('Mean reciprocal rank positivity increase from 01 - 14', fontsize=20)
plt.subplots_adjust(top=(j-1)/j)
plt.savefig('MRR_positivity_increase.jpeg', dpi=300)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
j = 0
for i in range(100):#len(top_slopes)):
    temp = bot_slopes[i][1]
    x = range(len(temp[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    y = []
    m = [*loop]
    c = [*loop]
    for z in loop: 
        y.append(temp[z])
        m[z], c[z] = np.linalg.lstsq(A, y[z])[0]
    if all(slope < -10 for slope in m):
        if j == 0:
            fig = plt.figure() #figsize = (10,500)
            ax = fig.add_subplot(111)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(bot_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        else:
            for k in range(j):
                fig.axes[k].change_geometry(j+1, 1, k+1)
            ax = fig.add_subplot(j+1, 1, j+1)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(bot_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        j += 1

#plt.subplots_adjust(hspace=0.25)
fig.set_size_inches(10, 2*j, forward=True)
fig.tight_layout()
fig.suptitle('Mean reciprocal rank negativity increase from 01 - 14', fontsize=20)
plt.subplots_adjust(top=(j-1)/j)
plt.savefig('MRR_negativity_increase.jpeg', dpi=300)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
j = 0
for i in range(100):#len(top_slopes)):
    temp = bot_slopes[i][1]
    x = range(len(temp[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    y = []
    m = [*loop]
    c = [*loop]
    for z in loop: 
        y.append(temp[z])
        m[z], c[z] = np.linalg.lstsq(A, y[z])[0]
    if all(slope > 10 for slope in m):
        if j == 0:
            fig = plt.figure() #figsize = (10,500)
            ax = fig.add_subplot(111)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(bot_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        else:
            for k in range(j):
                fig.axes[k].change_geometry(j+1, 1, k+1)
            ax = fig.add_subplot(j+1, 1, j+1)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, 0, 1500])
            plt.title(bot_slopes[i][0] + '               slope: ' + str([round(slope, 3) for slope in m]))
        j += 1

#plt.subplots_adjust(hspace=0.25)
fig.set_size_inches(10, 2*j, forward=True)
fig.tight_layout()
fig.suptitle('Mean reciprocal rank negativity degradation from 01 - 14', fontsize=20)
plt.subplots_adjust(top=(j-1)/j)
plt.savefig('MRR_negativity_degradation.jpeg', dpi=300)
plt.show()
# Out:
# D:\Programs\Anaconda\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
df = []
for z in loop:
    df.append(pd.DataFrame(data={k:v.coef_[0] for (k,v) in main[z]['models'].items()}, index=main[z]['features']))

# %%
for z in loop:
    df[z][df[z] > 0.01].dropna().index
    df[z][df[z] < -0.01].dropna().index

pos = []
neg = []

for z in loop:
    pos.append(list(df[z][df[z] > 0.001].dropna(thresh=5).index))
    neg.append(list(df[z][df[z] < -0.001].dropna(thresh=5).index))

# %%
temp = []
for z in loop:
    temp.append(set.intersection(set(pos[z]), set(neg[z])))
temp = list(set.intersection(*temp))
words = temp[:]
temp = []
print(words)
# Out:
# ['industry', 'fish', 'hey', 'religious', 'god', 'll be', 'ground', 'with all', 'the songs', 'problems', 'they would', 'girl', 'the quality', 'cost', 'christ', 'decided', 'to this', 'an old', 'to figure', 'kid', 'of god', 'are quite', 'cute', 'scientific', 'think', 'the dvd', 'chair', 'back the', 'sign', 'man', 'out to', 'new york', 'with its', 'it out', 'only reason', 'to listen', 'the bad', 'rarely', 'prefer', 'the name', 'younger', 'mark', 'form', 'to get', 'instead of', 'seller', 'thomas', 'the', 'newer', 'fact that', 'something like', 'is very', 'un', 'discs', 'are', 'however there', 'your own', 'protagonist', 'high', 'no one', 'actions', 'for the', 'one will', 'who are', 'as all', 'with other', 'was looking', 'baby', 'speaker', 'sing', 'to take', 'is for', 'series and', 'holy', 'pull', 'settings', 'exercise', 'one day', 'handle', 'cover', 'background', 'us that', 'best of', 'had more', 'king', 'fans', 'while you', 'setting', 'years and', 'hours', 'coffee', 'york', 'search', 'opp
# ...

# %%
'''for k in list(set(pos[0] + neg[0])):
    if k in pos[0] and k in neg[0]:
            temp = df[0].loc[k]
            x = range(len(temp))
            y = temp
            A = np.vstack([x, np.ones(len(x))]).T
            m, c, rval, pval, stderr = linregress(x, y)
            print(linregress(x, y))
            print('slope: ', m)
            plt.plot(x, y, 'o', label='Original data', markersize=10)
            plt.plot(x, m*x + c, 'r', label='Fitted line')
            plt.title(k)
            plt.show()'''
# Out:
# "for k in list(set(pos[0] + neg[0])):\n    if k in pos[0] and k in neg[0]:\n            temp = df[0].loc[k]\n            x = range(len(temp))\n            y = temp\n            A = np.vstack([x, np.ones(len(x))]).T\n            m, c, rval, pval, stderr = linregress(x, y)\n            print(linregress(x, y))\n            print('slope: ', m)\n            plt.plot(x, y, 'o', label='Original data', markersize=10)\n            plt.plot(x, m*x + c, 'r', label='Fitted line')\n            plt.title(k)\n            plt.show()"

# %%
j = 0
for i in words:
    temp = [df[z].loc[i] for z in loop]
    x = range(len(temp[0]))
    A = np.vstack([x, np.ones(len(x))]).T
    y = []
    m = [*loop]
    c = [*loop]
    rval = [*loop]
    pval = [*loop]
    stderr = [*loop]
    for z in loop: 
        y.append(temp[z])
        m[z], c[z], rval[z], pval[z], stderr[z] = linregress(x, y[z])
    if all(rv**2 > 0.35 for rv in rval):
        #print(round(m, 5), round(stderr, 7))
        if j == 0:
            fig = plt.figure() #figsize = (10,500)
            ax = fig.add_subplot(111)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, -0.2, 0.2])
            plt.title(i + '    R**2: ' + str([round(rv**2, 5) for rv in rval]) + '    slope: ' + str([round(slope, 3) for slope in m]) + '    stderr: ' + str([round(stde, 7) for stde in stderr]))
        else:
            for k in range(j):
                fig.axes[k].change_geometry(j+1, 1, k+1)
            ax = fig.add_subplot(j+1, 1, j+1)
            for z in loop:
                plt.plot(x, y[z], color=col[z], marker='o', ls='None', label='Original data', markersize=5)
                plt.plot(x, m[z]*x + c[z], color=col[z], label='Fitted line')
            plt.axis([1, 14, -0.2, 0.2])
            plt.title(i + '    R**2: ' + str([round(rv**2, 5) for rv in rval]) + '    slope: ' + str([round(slope, 3) for slope in m]) + '    stderr: ' + str([round(stde, 7) for stde in stderr]))
        j += 1
#plt.subplots_adjust(hspace=0.25)
fig.set_size_inches(10, 2*j, forward=True)
fig.tight_layout()
fig.suptitle('Polarity switching', fontsize=20)
plt.subplots_adjust(top=(j-1)/j)
plt.savefig('Polarity_switching.jpeg', dpi=300)
plt.show()
